# %% [raw]
# IMPORTS

# %%
import pandas as pd
import numpy as np
import time
import matplotlib.pyplot as plt

from tensorflow import keras
from keras.preprocessing.sequence import TimeseriesGenerator
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import Dropout


from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
# import tensorflow as tf; print(tf.__version__)
from itertools  import product

# %% [markdown]
# FUNCTIONS // THAT DONT CHANGE

# %%
def createdata(location , feature_list):
    
    data=pd.read_csv(location)
    Greece= data[data.location =='Greece'].reset_index(drop='True')
    Greece = Greece.dropna(how='all', axis=1)
    Greece_total = Greece.iloc[7:498, 3:40].reset_index(drop='True')
    
    Greece=Greece_total[(feature_list)]
    Greece["date"] = Greece_total['date']
    Greece=Greece.dropna(axis=0)
    dates=pd.DataFrame(Greece['date']).reset_index(drop=True)
    Greece=Greece[(feature_list)].reset_index(drop=True)
    
    return dates , Greece , Greece_total

def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

def split_data(data, sequence):
    train_set = data[:355].reset_index(drop=True)
    validation_set = data[355 - sequence:369].reset_index(drop=True)
    test_set = data[369 - sequence:].reset_index(drop=True) 
    
    return train_set, validation_set, test_set


def timeseries_gen(seq_size, n_features, train, val, test):
    # Train Set
    train_generator = TimeseriesGenerator(train, train.iloc[:, 0], length=seq_size, batch_size=1)
    print("Total number of samples in the original training data = ", len(train))
    print("Total number of samples in the generated training data = ", len(train_generator))


    # Validation Set
    val_generator = TimeseriesGenerator(val, val.iloc[:, 0], length=seq_size, batch_size=1)
    print("Total number of samples in the original validation data = ", len(val))
    print("Total number of samples in the validation data = ", len(val_generator))

    # Test Set
    test_generator = TimeseriesGenerator(test, test.iloc[:, 0], length=seq_size, batch_size=1)
    print("Total number of samples in the original test data = ", len(test))
    print("Total number of samples in the generated test data = ", len(test_generator))
    return train_generator, val_generator, test_generator


def plotloss(mod, name=""):
    plt.figure(figsize=[12,10] , dpi=140 )
    loss = mod.history['loss']
    val_loss = mod.history['val_loss']
    epochs = range(1, len(loss) + 1)
    plt.plot(epochs, loss, 'y', label='Training loss')
    plt.plot(epochs, val_loss, 'r', label='Validation loss')
    plt.title('Training and validation loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    # plt.savefig("Plots\loss_model" + name +".jpeg"  )
    plt.show()


def plotprediction(ypredict , name=""):
    plt.figure(figsize=[12,10] , dpi=140 )
    plt.plot(ypredict.index, ypredict.iloc[:, 0], 'y', label='Prediction ')
    plt.plot(ypredict.index, ypredict.iloc[:, 1], 'r', label='Actual ')
    plt.title('Predicted vs  Actual Cases in Greece for ' +str(len(ypredict)) + ' days')
    plt.xlabel('Date')
    plt.ylabel('Cases')
    plt.legend()
    # plt.savefig("Plots\pred" + name +".jpeg"  )
    plt.show()
   


def inversesets(sequence,feature_list, sc, trainset, validationset, testset, ogdata, dates):
    
    drange =dates.loc[0]
    drange=pd.to_datetime(drange["date"])
    date_index = pd.date_range(drange , periods=len(dates), freq='D')

    
    
    set1 = pd.DataFrame(sc.inverse_transform(trainset),index=date_index[0:len(trainset)])

    set1=set1.set_axis(feature_list, axis=1, inplace=False)
    
    set2 = pd.DataFrame(sc.inverse_transform(validationset),index=date_index[len(trainset) - sequence:len(trainset) + len(validationset) - sequence])
    set2=set2.set_axis(feature_list, axis=1, inplace=False)

    set3 = pd.DataFrame(sc.inverse_transform(testset),index=date_index[-len(testset):])
    set3=set3.set_axis(feature_list, axis=1, inplace=False)
    return set1, set2, set3

# %% [markdown]
# MODEL CREATION , TRAINING , PREDICTION

# %%
def model_create(nodes, seq_size , features):
    model = Sequential()
    model.add(LSTM(nodes, activation='relu' ,return_sequences=True, input_shape=(seq_size, features)))
    model.add(LSTM(nodes, return_sequences = True))
    model.add(LSTM(nodes, return_sequences = False))
    model.add(Dense(1))
    model.compile(optimizer='Adam', loss='mean_squared_error')
    model.summary()
    return model

# %% [markdown]
# TRAIN NO PLOTS

# %%
def model_train(i, model, traingenerator, valgenerator, ep):
    history = model.fit(traingenerator, validation_data=valgenerator, epochs=ep,batch_size=4 ,verbose=1)
    # model.save('Models\model_' + str(i) + '.h5', overwrite=True)
    plotloss(history,str(i))
    return model

# %% [markdown]
# PREDICT

# %%
def predict(model, sc, valgenerator, validation_set, inverseval, trainset ):
    

    # Forecast   Predict using a for loop
    index = inverseval.index
    predictiondata = pd.DataFrame(inverseval[:seq_size])  # Empty list to populate later with predictions
    predictiondata = pd.DataFrame(trainset[-seq_size:]).reset_index(drop=True)
    current_batch = trainset[-seq_size:]
    forecast = pd.DataFrame()

    # Predict future, beyond test dates
    future = len(validation_set) - seq_size  # Days
    for i in range(future):
                
        current_batch = predictiondata[i:seq_size + i] #Create input for LSTM (Based on sequence size )

        current_batch = current_batch.to_numpy()  #Input to array 

        current_batch = current_batch.reshape(1, seq_size, n_features)  # Reshape

        ### Prediction ##
        
        current_pred = model.predict(current_batch) # Make a prediction 
        current_pred = float(current_pred[0]) #Convert Prediction to integer 
        predictiondata.loc[len(predictiondata.index)] = [current_pred]   

    forecast = predictiondata[-(future):] #Save results in a dataframe 
    forecast = sc.inverse_transform(forecast)#Inverse Transform to get the actual cases 
    forecast = pd.DataFrame(forecast.round()) #Round results 
    forecast = forecast.set_index(index[seq_size:], 'Date').rename(columns={0: 'Prediction'})

    forecast = pd.concat([forecast['Prediction'], inverseval['total_cases'][seq_size:]], axis=1 ,ignore_index=True) #Concate the two dfs 

    forecast=forecast.set_axis(['Prediction', 'Actual'], axis=1, inplace=False)
    
    
    return forecast

# %% [markdown]
# HYPERPARAMETERS

# %%
def Hyper(parameter1 , parameter2 , repetitions):
    hp1 = list(product(parameter1 , parameter2 ))
    # Hyperparameters = list (product(hp1 , parameter3))
    Hyperparameters= pd.DataFrame(hp1).rename(columns={0: "Nodes", 1: "Epochs"})
    
    # Hyperparameters[['Learning Rate' , 'Epochs']]= pd.DataFrame(Hyperparameters['A'].tolist(), index=Hyperparameters.index)
    
    Hyperparameters=Hyperparameters.sort_values(by=['Nodes' ,'Epochs' ])
    Hyperparameters=pd.concat([Hyperparameters]*times)
    
    
    Hyperparameters= list(Hyperparameters.itertuples(index=False, name=None))
    
    
    return Hyperparameters

# %% [markdown]
# CLUSTER FUCK LSTM

# %%
def experiments(times, nodes, scaler, seq_size, epochs, n_features, train_generator, val_generator, validation_set,
                train_set, inv_val, inv_test, dates ):
    
    experimentmodel = model_create(nodes, seq_size ,n_features )

    experimentmodel = model_train(i, experimentmodel, train_generator, val_generator, epochs)  # Train Model

    forecast = predict(experimentmodel, scaler, val_generator, validation_set, inv_val, train_set)
    plotprediction(forecast ,str(i))
    
    
    ##################### Metrics ######################

    mae_4 = mean_absolute_error(forecast['Actual'], forecast['Prediction'])
    MAE_4.append(mae_4)

    mape_4 = mean_absolute_percentage_error(forecast['Actual'], forecast['Prediction'])
    MAPE_4.append(mape_4)

    mse_4 = mean_squared_error(forecast['Actual'], forecast['Prediction'])
    MSE_4.append(mse_4)

    rmse_4 = mean_squared_error(forecast['Actual'], forecast['Prediction'], squared=False)
    RMSE_4.append(rmse_4)

    node.append(nodes)


    mape_4_next_day = mean_absolute_percentage_error(forecast['Actual'][:1], forecast['Prediction'][:1])
    MAPE_4_Next_day.append(mape_4_next_day)
 
    mape_3days = mean_absolute_percentage_error(forecast['Actual'][:3], forecast['Prediction'][:3])
    MAPE_4_3days.append(mape_3days)
    
    mape_7days = mean_absolute_percentage_error(forecast['Actual'][:7], forecast['Prediction'][:7])
    MAPE_4_7days.append(mape_7days)
    
    Epochs.append(epochs)
        

    return

# %% [markdown]
# PARAMTERS

# %%
Windeos_loc="owid-covid-data.csv"
feature_list=["total_cases"]
n_features = len(feature_list)
seq_size = 3

times = 10 #For each experiment

epochs = [50, 60]
nodes = [18, 20, 22, 25 , 30]

# %% [markdown]
# MAIN LOOP

# %%
Hyperparameters= Hyper(nodes, epochs ,times )




dates,greece , Greece_total =createdata('owid-covid-data.csv',feature_list)
train_set, validation_set, test_set = split_data( greece, seq_size)
scaler = MinMaxScaler() 
scaler.fit(train_set)
train_set=pd.DataFrame(scaler.transform(train_set))
train_set=train_set.set_axis(feature_list, axis=1, inplace=False)
validation_set=pd.DataFrame(scaler.transform(validation_set))
validation_set=validation_set.set_axis(feature_list, axis=1, inplace=False)
test_set=pd.DataFrame(scaler.transform(test_set))
test_set=test_set.set_axis(feature_list, axis=1, inplace=False)
train_generator, val_generator, test_generator = timeseries_gen(seq_size, n_features, train_set, validation_set, test_set)
inv_train, inv_val, inv_test = inversesets(seq_size,feature_list, scaler, train_set, validation_set, test_set, greece,dates)


Epochs = []
node = []
MAE_4 = []
MAPE_4 = []
MSE_4 = []
RMSE_4 = []
MAPE_4_3days = []
MAPE_4_7days = []
MAPE_4_Next_day = []



# for i in  range(len(Hyperparameters)):
for i in  range(10):
    
    nodes  ,  epochs = 44 , 30 
    experiments(i, nodes, scaler, seq_size, epochs, n_features, train_generator, val_generator,validation_set, train_set, inv_val, inv_test, dates )
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# Total number of samples in the original training data =  355
# Total number of samples in the generated training data =  352
# Total number of samples in the original validation data =  17
# Total number of samples in the validation data =  14
# Total number of samples in the original test data =  125
# Total number of samples in the generated test data =  122
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 3, 18)             1440
#
#  lstm_1 (LSTM)               (None, 18)                2664
#
#  dense (Dense)               (None, 1)                 19
#
# =================================================================
# Total params: 4,123
# Trainable params: 4,123
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 352/352 [==============================] - 5s 6ms/step - loss: 0.0322 - val_loss: 1.5681e-04
# Epoch 2/50
# 352/352 [==============================] - 1s 4ms/step - loss: 1.9231e-04 - val_loss: 1.1400e-04
# Epoch 3/50
# 352/352 [==============================] - 1s 4ms/step - loss: 5.7310e-05 - val_loss: 1.6981e-05
# Epoch 4/50
# 352/352 [==============================] - 1s 4ms/step - loss: 1.8121e-05 - val_loss: 4.1858e-05
# Epoch 5/50
# 352/352 [==============================] - 1s 4ms/step - loss: 1.0790e-05 - val_loss: 6.3984e-05
# Epoch 6/50
# 352/352 [==============================] - 1s 4ms/step - loss: 1.4439e-05 - val_loss: 4.3011e-05
# Epoch 7/50
# 352/352 [==============================] - 1s 4ms/step - loss: 2.3490e-05 - val_loss: 3.4376e-05
# Epoch 8/50
# 352/352 [==============================] - 1s 4ms/step - loss: 4.2987e-05 - val_loss: 9.5446e-05
# Epoch 9/50
# 352/352 [==============================] - 1s 4ms/step - loss: 4.9006e-05 - val_loss: 2.3668e-04
# Epoch 10/50
# 352/352 [==============================] - 1s 4ms/step - loss: 5.5723e-05 - val_loss: 1.2380e-04
# Epoch 11/50
# 352/352 [==============================] - 1s 4ms/step - loss: 9.3455e-05 - val_loss: 4.3618e-05
# Epoch 12/50
# 352/352 [==============================] - 1s 4ms/step - loss: 2.8790e-05 - val_loss: 3.1492e-05
# Epoch 13/50
# 352/352 [==============================] - 1s 4ms/step - loss: 3.3685e-05 - val_loss: 1.2808e-04
# Epoch 14/50
# 352/352 [==============================] - 1s 4ms/step - loss: 9.7454e-05 - val_loss: 1.5543e-04
# Epoch 15/50
# 352/352 [==============================] - 1s 4ms/step - loss: 5.2369e-05 - val_loss: 8.3201e-05
# Epoch 16/50
# 352/352 [==============================] - 1s 4ms/step - loss: 6.0924e-05 - val_loss: 9.7501e-04
# Epoch 17/50
# 352/352 [==============================] - 1s 4ms/step - loss: 4.9919e-04 - val_loss: 3.2081e-04
# Epoch 18/50
# 352/352 [==============================] - 1s 4ms/step - loss: 1.9760e-05 - val_loss: 2.5589e-05
# Epoch 19/50
# 352/352 [==============================] - 1s 4ms/step - loss: 3.4127e-05 - val_loss: 0.0011
# Epoch 20/50
# 352/352 [==============================] - 1s 4ms/step - loss: 2.4212e-05 - val_loss: 6.4677e-05
# Epoch 21/50
# 352/352 [==============================] - 1s 4ms/step - loss: 4.8439e-05 - val_loss: 1.4048e-04
# Epoch 22/50
# 352/352 [==============================] - 1s 4ms/step - loss: 3.4075e-05 - val_loss: 3.9106e-04
# Epoch 23/50
# 352/352 [==============================] - 1s 4ms/step - loss: 7.2688e-05 - val_loss: 3.0210e-05
# Epoch 24/50
# 352/352 [==============================] - 1s 4ms/step - loss: 2.8110e-05 - val_loss: 0.0043
# Epoch 25/50
# 352/352 [==============================] - 1s 4ms/step - loss: 2.0289e-04 - val_loss: 3.1269e-04
# Epoch 26/50
# 352/352 [==============================] - 1s 4ms/step - loss: 3.8509e-05 - val_loss: 7.8266e-05
# Epoch 27/50
# 352/352 [==============================] - 1s 4ms/step - loss: 6.3520e-05 - val_loss: 9.3089e-05
# Epoch 28/50
# 352/352 [==============================] - 1s 4ms/step - loss: 4.5840e-05 - val_loss: 5.2023e-04
# Epoch 29/50
# 352/352 [==============================] - 1s 4ms/step - loss: 4.6114e-05 - val_loss: 7.8849e-05
# Epoch 30/50
# 352/352 [==============================] - 1s 4ms/step - loss: 8.6518e-05 - val_loss: 2.0522e-04
# Epoch 31/50
# 352/352 [==============================] - 1s 4ms/step - loss: 3.2847e-05 - val_loss: 6.3202e-05
# Epoch 32/50
# 352/352 [==============================] - 1s 4ms/step - loss: 5.7035e-05 - val_loss: 9.5060e-05
# Epoch 33/50
# 352/352 [==============================] - 1s 4ms/step - loss: 4.8263e-05 - val_loss: 2.0760e-04
# Epoch 34/50
# 352/352 [==============================] - 1s 4ms/step - loss: 5.9174e-05 - val_loss: 8.2481e-05
# Epoch 35/50
# 352/352 [==============================] - 1s 4ms/step - loss: 4.6959e-05 - val_loss: 2.4410e-04
# Epoch 36/50
# 352/352 [==============================] - 1s 4ms/step - loss: 3.6443e-05 - val_loss: 0.0014
# Epoch 37/50
# 352/352 [==============================] - 1s 4ms/step - loss: 1.8043e-04 - val_loss: 1.6797e-04
# Epoch 38/50
# 352/352 [==============================] - 1s 4ms/step - loss: 2.8225e-05 - val_loss: 6.3386e-05
# Epoch 39/50
# 352/352 [==============================] - 1s 4ms/step - loss: 4.3481e-05 - val_loss: 7.1332e-04
# Epoch 40/50
# 352/352 [==============================] - 1s 4ms/step - loss: 6.6211e-05 - val_loss: 1.5848e-05
# Epoch 41/50
# 352/352 [==============================] - 1s 4ms/step - loss: 3.1635e-05 - val_loss: 2.4052e-05
# Epoch 42/50
# 352/352 [==============================] - 1s 4ms/step - loss: 3.9748e-05 - val_loss: 0.0015
# Epoch 43/50
# 352/352 [==============================] - 1s 4ms/step - loss: 2.4264e-04 - val_loss: 5.8310e-05
# Epoch 44/50
# 352/352 [==============================] - 1s 4ms/step - loss: 2.6818e-05 - val_loss: 2.0307e-04
# Epoch 45/50
# 352/352 [==============================] - 1s 4ms/step - loss: 2.2491e-05 - val_loss: 8.6844e-04
# Epoch 46/50
# 352/352 [==============================] - 1s 4ms/step - loss: 2.4833e-05 - val_loss: 9.4855e-05
# Epoch 47/50
# 352/352 [==============================] - 1s 4ms/step - loss: 1.0418e-04 - val_loss: 1.2627e-04
# Epoch 48/50
# 352/352 [==============================] - 1s 4ms/step - loss: 2.0344e-05 - val_loss: 1.5794e-04
# Epoch 49/50
# 352/352 [==============================] - 1s 4ms/step - loss: 7.5503e-05 - val_loss: 8.6167e-05
# Epoch 50/50
# 352/352 [==============================] - 1s 4ms/step - loss: 3.9873e-05 - val_loss: 4.8189e-05
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_2 (LSTM)               (None, 3, 18)             1440
#
#  lstm_3 (LSTM)               (None, 18)                2664
#
#  dense_1 (Dense)             (None, 1)                 19
#
# =================================================================
# Total params: 4,123
# Trainable params: 4,123
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/60
# 352/352 [==============================] - 4s 5ms/step - loss: 0.0366 - val_loss: 6.8158e-04
# Epoch 2/60
# 352/352 [==============================] - 1s 4ms/step - loss: 1.9520e-04 - val_loss: 0.0012
# Epoch 3/60
# 352/352 [==============================] - 1s 4ms/step - loss: 1.0776e-04 - val_loss: 0.0021
# Epoch 4/60
# 352/352 [==============================] - 1s 4ms/step - loss: 5.1524e-05 - val_loss: 1.2152e-04
# Epoch 5/60
# 352/352 [==============================] - 1s 4ms/step - loss: 4.3731e-05 - val_loss: 2.4570e-04
# Epoch 6/60
# 352/352 [==============================] - 1s 4ms/step - loss: 2.5250e-05 - val_loss: 1.0176e-04
# Epoch 7/60
# 352/352 [==============================] - 1s 4ms/step - loss: 1.6211e-05 - val_loss: 2.5957e-04
# Epoch 8/60
# 352/352 [==============================] - 1s 4ms/step - loss: 2.6906e-05 - val_loss: 2.0444e-05
# Epoch 9/60
# 352/352 [==============================] - 1s 4ms/step - loss: 2.1538e-05 - val_loss: 2.3102e-05
# Epoch 10/60
# 352/352 [==============================] - 1s 4ms/step - loss: 2.3862e-05 - val_loss: 0.0040
# Epoch 11/60
# 352/352 [==============================] - 1s 4ms/step - loss: 9.6003e-05 - val_loss: 3.3558e-04
# Epoch 12/60
# 352/352 [==============================] - 2s 4ms/step - loss: 3.1578e-05 - val_loss: 2.2475e-05
# Epoch 13/60
# 352/352 [==============================] - 2s 4ms/step - loss: 2.3227e-05 - val_loss: 6.5329e-05
# Epoch 14/60
# 352/352 [==============================] - 2s 4ms/step - loss: 1.6663e-04 - val_loss: 7.5263e-05
# Epoch 15/60
# 352/352 [==============================] - 1s 4ms/step - loss: 7.7431e-05 - val_loss: 2.4493e-04
# Epoch 16/60
# 352/352 [==============================] - 2s 4ms/step - loss: 6.3384e-05 - val_loss: 3.3493e-05
# Epoch 17/60
# 352/352 [==============================] - 2s 4ms/step - loss: 3.8680e-05 - val_loss: 2.5468e-05
# Epoch 18/60
# 352/352 [==============================] - 2s 4ms/step - loss: 5.3697e-05 - val_loss: 3.3652e-04
# Epoch 19/60
# 352/352 [==============================] - 2s 4ms/step - loss: 6.3109e-05 - val_loss: 2.5303e-05
# Epoch 20/60
# 352/352 [==============================] - 2s 4ms/step - loss: 4.0627e-05 - val_loss: 0.0013
# Epoch 21/60
# 352/352 [==============================] - 2s 4ms/step - loss: 2.7958e-04 - val_loss: 0.0028
# Epoch 22/60
# 352/352 [==============================] - 2s 4ms/step - loss: 5.2134e-05 - val_loss: 3.5786e-05
# Epoch 23/60
# 352/352 [==============================] - 2s 4ms/step - loss: 2.7035e-05 - val_loss: 2.9493e-04
# Epoch 24/60
# 352/352 [==============================] - 2s 4ms/step - loss: 1.2936e-04 - val_loss: 1.1642e-04
# Epoch 25/60
# 352/352 [==============================] - 2s 4ms/step - loss: 3.9077e-05 - val_loss: 2.7161e-05
# Epoch 26/60
# 352/352 [==============================] - 2s 4ms/step - loss: 1.6592e-05 - val_loss: 2.5622e-05
# Epoch 27/60
# 352/352 [==============================] - 2s 4ms/step - loss: 6.5526e-05 - val_loss: 1.8590e-04
# Epoch 28/60
# 352/352 [==============================] - 2s 4ms/step - loss: 1.7001e-04 - val_loss: 7.6135e-04
# Epoch 29/60
# 352/352 [==============================] - 2s 4ms/step - loss: 2.7876e-05 - val_loss: 7.4908e-05
# Epoch 30/60
# 352/352 [==============================] - 2s 4ms/step - loss: 9.0707e-05 - val_loss: 3.3663e-05
# Epoch 31/60
# 352/352 [==============================] - 2s 4ms/step - loss: 4.5572e-05 - val_loss: 2.0961e-05
# Epoch 32/60
# 352/352 [==============================] - 2s 4ms/step - loss: 4.5581e-05 - val_loss: 0.0032
# Epoch 33/60
# 352/352 [==============================] - 2s 4ms/step - loss: 7.0693e-05 - val_loss: 1.8880e-04
# Epoch 34/60
# 352/352 [==============================] - 2s 5ms/step - loss: 2.9032e-05 - val_loss: 4.1210e-04
# Epoch 35/60
# 352/352 [==============================] - 2s 4ms/step - loss: 7.0405e-05 - val_loss: 2.2738e-04
# Epoch 36/60
# 352/352 [==============================] - 2s 5ms/step - loss: 4.6147e-05 - val_loss: 2.2744e-04
# Epoch 37/60
# 352/352 [==============================] - 2s 5ms/step - loss: 8.7285e-05 - val_loss: 3.5621e-04
# Epoch 38/60
# 352/352 [==============================] - 2s 4ms/step - loss: 5.8344e-05 - val_loss: 2.8354e-05
# Epoch 39/60
# 352/352 [==============================] - 2s 4ms/step - loss: 2.9264e-05 - val_loss: 3.8530e-04
# Epoch 40/60
# 352/352 [==============================] - 2s 4ms/step - loss: 4.3991e-05 - val_loss: 7.7776e-05
# Epoch 41/60
# 352/352 [==============================] - 2s 4ms/step - loss: 5.1099e-05 - val_loss: 0.0011
# Epoch 42/60
# 352/352 [==============================] - 2s 4ms/step - loss: 8.6582e-05 - val_loss: 2.2023e-05
# Epoch 43/60
# 352/352 [==============================] - 2s 4ms/step - loss: 6.6009e-05 - val_loss: 4.2043e-05
# Epoch 44/60
# 352/352 [==============================] - 2s 4ms/step - loss: 1.8589e-05 - val_loss: 2.0667e-05
# Epoch 45/60
# 352/352 [==============================] - 2s 4ms/step - loss: 5.6980e-05 - val_loss: 2.4005e-05
# Epoch 46/60
# 352/352 [==============================] - 2s 4ms/step - loss: 5.2442e-05 - val_loss: 1.4169e-04
# Epoch 47/60
# 352/352 [==============================] - 2s 4ms/step - loss: 3.7159e-05 - val_loss: 1.3203e-04
# Epoch 48/60
# 352/352 [==============================] - 2s 4ms/step - loss: 4.8607e-05 - val_loss: 1.7245e-04
# Epoch 49/60
# 352/352 [==============================] - 2s 4ms/step - loss: 8.8874e-05 - val_loss: 2.7875e-04
# Epoch 50/60
# 352/352 [==============================] - 2s 4ms/step - loss: 3.0063e-05 - val_loss: 1.6577e-05
# Epoch 51/60
# 352/352 [==============================] - 2s 4ms/step - loss: 1.1602e-04 - val_loss: 6.4572e-05
# Epoch 52/60
# 352/352 [==============================] - 2s 5ms/step - loss: 2.2862e-05 - val_loss: 1.5840e-05
# Epoch 53/60
# 352/352 [==============================] - 2s 4ms/step - loss: 2.5163e-05 - val_loss: 3.2828e-05
# Epoch 54/60
# 352/352 [==============================] - 2s 4ms/step - loss: 5.8701e-05 - val_loss: 5.6707e-05
# Epoch 55/60
# 352/352 [==============================] - 2s 4ms/step - loss: 3.8696e-05 - val_loss: 3.7235e-04
# Epoch 56/60
# 352/352 [==============================] - 2s 5ms/step - loss: 2.7359e-05 - val_loss: 1.7650e-05
# Epoch 57/60
# 352/352 [==============================] - 2s 4ms/step - loss: 2.4031e-05 - val_loss: 2.7017e-05
# Epoch 58/60
# 352/352 [==============================] - 2s 4ms/step - loss: 4.9622e-05 - val_loss: 1.9815e-05
# Epoch 59/60
# 352/352 [==============================] - 2s 4ms/step - loss: 6.1407e-05 - val_loss: 3.3032e-04
# Epoch 60/60
# 352/352 [==============================] - 2s 4ms/step - loss: 4.5678e-05 - val_loss: 1.8409e-05
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_4 (LSTM)               (None, 3, 20)             1760
#
#  lstm_5 (LSTM)               (None, 20)                3280
#
#  dense_2 (Dense)             (None, 1)                 21
#
# =================================================================
# Total params: 5,061
# Trainable params: 5,061
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 352/352 [==============================] - 5s 5ms/step - loss: 0.0277 - val_loss: 0.0012
# Epoch 2/50
# 352/352 [==============================] - 1s 4ms/step - loss: 4.3979e-05 - val_loss: 3.0097e-04
# Epoch 3/50
# 352/352 [==============================] - 1s 4ms/step - loss: 1.4244e-05 - val_loss: 1.8051e-04
# Epoch 4/50
# 352/352 [==============================] - 2s 4ms/step - loss: 1.5607e-05 - val_loss: 4.7734e-05
# Epoch 5/50
# 352/352 [==============================] - 2s 5ms/step - loss: 1.2309e-05 - val_loss: 1.6056e-04
# Epoch 6/50
# 352/352 [==============================] - 2s 5ms/step - loss: 3.3057e-05 - val_loss: 1.4155e-04
# Epoch 7/50
# 352/352 [==============================] - 2s 5ms/step - loss: 3.5837e-05 - val_loss: 2.9254e-04
# Epoch 8/50
# 352/352 [==============================] - 2s 5ms/step - loss: 3.9290e-05 - val_loss: 9.5012e-05
# Epoch 9/50
# 352/352 [==============================] - 2s 5ms/step - loss: 8.6132e-05 - val_loss: 1.4064e-04
# Epoch 10/50
# 352/352 [==============================] - 2s 5ms/step - loss: 1.4338e-04 - val_loss: 2.9398e-05
# Epoch 11/50
# 352/352 [==============================] - 2s 5ms/step - loss: 2.4292e-05 - val_loss: 1.0074e-04
# Epoch 12/50
# 352/352 [==============================] - 2s 5ms/step - loss: 7.2674e-05 - val_loss: 8.6808e-05
# Epoch 13/50
# 352/352 [==============================] - 2s 5ms/step - loss: 1.7888e-04 - val_loss: 2.6934e-05
# Epoch 14/50
# 352/352 [==============================] - 2s 5ms/step - loss: 6.6596e-05 - val_loss: 1.1046e-04
# Epoch 15/50
# 352/352 [==============================] - 2s 5ms/step - loss: 6.4172e-05 - val_loss: 1.9212e-05
# Epoch 16/50
# 352/352 [==============================] - 2s 5ms/step - loss: 4.4250e-05 - val_loss: 3.1299e-04
# Epoch 17/50
# 352/352 [==============================] - 2s 5ms/step - loss: 9.5705e-05 - val_loss: 1.9848e-04
# Epoch 18/50
# 352/352 [==============================] - 2s 5ms/step - loss: 1.5474e-04 - val_loss: 6.3680e-04
# Epoch 19/50
# 352/352 [==============================] - 2s 5ms/step - loss: 1.3628e-04 - val_loss: 2.3912e-05
# Epoch 20/50
# 352/352 [==============================] - 2s 5ms/step - loss: 6.7352e-05 - val_loss: 5.4192e-05
# Epoch 21/50
# 352/352 [==============================] - 2s 5ms/step - loss: 1.3860e-04 - val_loss: 6.3678e-04
# Epoch 22/50
# 352/352 [==============================] - 2s 5ms/step - loss: 3.0630e-05 - val_loss: 3.5613e-05
# Epoch 23/50
# 352/352 [==============================] - 2s 5ms/step - loss: 6.7485e-05 - val_loss: 1.8328e-05
# Epoch 24/50
# 352/352 [==============================] - 2s 5ms/step - loss: 2.0705e-04 - val_loss: 2.2493e-05
# Epoch 25/50
# 352/352 [==============================] - 2s 5ms/step - loss: 7.1207e-05 - val_loss: 1.0262e-04
# Epoch 26/50
# 352/352 [==============================] - 2s 5ms/step - loss: 2.6856e-05 - val_loss: 4.2081e-04
# Epoch 27/50
# 352/352 [==============================] - 2s 5ms/step - loss: 2.5970e-05 - val_loss: 2.0781e-05
# Epoch 28/50
# 352/352 [==============================] - 2s 5ms/step - loss: 1.8044e-04 - val_loss: 3.5899e-05
# Epoch 29/50
# 352/352 [==============================] - 2s 5ms/step - loss: 9.9170e-05 - val_loss: 2.3882e-04
# Epoch 30/50
# 352/352 [==============================] - 2s 5ms/step - loss: 3.4120e-05 - val_loss: 8.4707e-05
# Epoch 31/50
# 352/352 [==============================] - 2s 5ms/step - loss: 9.0712e-05 - val_loss: 4.7243e-04
# Epoch 32/50
# 352/352 [==============================] - 2s 4ms/step - loss: 4.1220e-05 - val_loss: 1.9414e-04
# Epoch 33/50
# 352/352 [==============================] - 2s 4ms/step - loss: 5.2423e-05 - val_loss: 1.7298e-05
# Epoch 34/50
# 352/352 [==============================] - 2s 5ms/step - loss: 2.5131e-05 - val_loss: 3.7481e-05
# Epoch 35/50
# 352/352 [==============================] - 2s 4ms/step - loss: 1.4624e-04 - val_loss: 2.6988e-04
# Epoch 36/50
# 352/352 [==============================] - 2s 5ms/step - loss: 1.0652e-04 - val_loss: 1.2665e-04
# Epoch 37/50
# 352/352 [==============================] - 2s 5ms/step - loss: 2.6604e-05 - val_loss: 1.8522e-04
# Epoch 38/50
# 352/352 [==============================] - 2s 5ms/step - loss: 1.1505e-04 - val_loss: 2.1897e-05
# Epoch 39/50
# 352/352 [==============================] - 2s 5ms/step - loss: 2.2609e-05 - val_loss: 9.4949e-04
# Epoch 40/50
# 352/352 [==============================] - 2s 5ms/step - loss: 5.1213e-05 - val_loss: 2.9981e-05
# Epoch 41/50
# 352/352 [==============================] - 2s 5ms/step - loss: 1.7495e-04 - val_loss: 9.0256e-05
# Epoch 42/50
# 352/352 [==============================] - 2s 5ms/step - loss: 5.0138e-05 - val_loss: 3.3522e-05
# Epoch 43/50
# 352/352 [==============================] - 2s 5ms/step - loss: 8.0075e-05 - val_loss: 4.6529e-04
# Epoch 44/50
# 352/352 [==============================] - 2s 5ms/step - loss: 3.9914e-05 - val_loss: 2.2007e-04
# Epoch 45/50
# 352/352 [==============================] - 2s 5ms/step - loss: 6.1000e-05 - val_loss: 1.2430e-04
# Epoch 46/50
# 352/352 [==============================] - 2s 5ms/step - loss: 8.3398e-05 - val_loss: 1.1678e-04
# Epoch 47/50
# 352/352 [==============================] - 2s 5ms/step - loss: 3.8064e-05 - val_loss: 1.9269e-04
# Epoch 48/50
# 352/352 [==============================] - 2s 5ms/step - loss: 2.9615e-05 - val_loss: 5.0239e-04
# Epoch 49/50
# 352/352 [==============================] - 2s 5ms/step - loss: 5.3824e-05 - val_loss: 8.2219e-05
# Epoch 50/50
# 352/352 [==============================] - 2s 5ms/step - loss: 1.0013e-04 - val_loss: 9.3563e-05
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_6 (LSTM)               (None, 3, 20)             1760
#
#  lstm_7 (LSTM)               (None, 20)                3280
#
#  dense_3 (Dense)             (None, 1)                 21
#
# =================================================================
# Total params: 5,061
# Trainable params: 5,061
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/60
# 352/352 [==============================] - 5s 6ms/step - loss: 0.0409 - val_loss: 0.0077
# Epoch 2/60
# 352/352 [==============================] - 1s 4ms/step - loss: 2.1725e-04 - val_loss: 0.0036
# Epoch 3/60
# 352/352 [==============================] - 2s 4ms/step - loss: 1.6263e-04 - val_loss: 0.0027
# Epoch 4/60
# 352/352 [==============================] - 2s 4ms/step - loss: 1.1773e-04 - val_loss: 0.0032
# Epoch 5/60
# 352/352 [==============================] - 2s 4ms/step - loss: 8.9264e-05 - val_loss: 0.0023
# Epoch 6/60
# 352/352 [==============================] - 2s 5ms/step - loss: 7.9951e-05 - val_loss: 6.9050e-04
# Epoch 7/60
# 352/352 [==============================] - 2s 4ms/step - loss: 7.3782e-05 - val_loss: 0.0021
# Epoch 8/60
# 352/352 [==============================] - 2s 4ms/step - loss: 7.1704e-05 - val_loss: 0.0017
# Epoch 9/60
# 352/352 [==============================] - 2s 4ms/step - loss: 3.6074e-05 - val_loss: 0.0034
# Epoch 10/60
# 352/352 [==============================] - 2s 4ms/step - loss: 5.2473e-05 - val_loss: 4.4522e-04
# Epoch 11/60
# 352/352 [==============================] - 2s 4ms/step - loss: 7.3000e-05 - val_loss: 7.1331e-04
# Epoch 12/60
# 352/352 [==============================] - 2s 4ms/step - loss: 4.6006e-05 - val_loss: 4.1428e-04
# Epoch 13/60
# 352/352 [==============================] - 2s 5ms/step - loss: 4.4530e-05 - val_loss: 2.0656e-04
# Epoch 14/60
# 352/352 [==============================] - 2s 5ms/step - loss: 1.9365e-04 - val_loss: 0.0022
# Epoch 15/60
# 352/352 [==============================] - 2s 5ms/step - loss: 2.2433e-04 - val_loss: 3.8469e-04
# Epoch 16/60
# 352/352 [==============================] - 2s 4ms/step - loss: 4.6879e-05 - val_loss: 5.0276e-04
# Epoch 17/60
# 352/352 [==============================] - 2s 4ms/step - loss: 4.1025e-05 - val_loss: 2.5857e-04
# Epoch 18/60
# 352/352 [==============================] - 2s 5ms/step - loss: 5.3041e-05 - val_loss: 1.7854e-04
# Epoch 19/60
# 352/352 [==============================] - 2s 5ms/step - loss: 5.4523e-05 - val_loss: 1.2488e-04
# Epoch 20/60
# 352/352 [==============================] - 2s 4ms/step - loss: 7.3822e-05 - val_loss: 5.6307e-04
# Epoch 21/60
# 352/352 [==============================] - 2s 4ms/step - loss: 5.2273e-05 - val_loss: 0.0021
# Epoch 22/60
# 352/352 [==============================] - 2s 4ms/step - loss: 8.8421e-05 - val_loss: 3.3791e-04
# Epoch 23/60
# 352/352 [==============================] - 2s 5ms/step - loss: 1.2811e-04 - val_loss: 1.3552e-04
# Epoch 24/60
# 352/352 [==============================] - 2s 5ms/step - loss: 9.8081e-05 - val_loss: 4.8526e-04
# Epoch 25/60
# 352/352 [==============================] - 2s 5ms/step - loss: 3.4960e-05 - val_loss: 0.0011
# Epoch 26/60
# 352/352 [==============================] - 2s 5ms/step - loss: 7.4333e-05 - val_loss: 0.0027
# Epoch 27/60
# 352/352 [==============================] - 2s 5ms/step - loss: 8.9095e-05 - val_loss: 8.7956e-04
# Epoch 28/60
# 352/352 [==============================] - 2s 5ms/step - loss: 8.0812e-05 - val_loss: 3.7739e-04
# Epoch 29/60
# 352/352 [==============================] - 2s 5ms/step - loss: 3.4487e-05 - val_loss: 6.4125e-04
# Epoch 30/60
# 352/352 [==============================] - 2s 5ms/step - loss: 8.3181e-05 - val_loss: 1.9554e-04
# Epoch 31/60
# 352/352 [==============================] - 2s 4ms/step - loss: 2.8029e-05 - val_loss: 0.0018
# Epoch 32/60
# 352/352 [==============================] - 2s 5ms/step - loss: 6.7962e-05 - val_loss: 0.0019
# Epoch 33/60
# 352/352 [==============================] - 2s 4ms/step - loss: 1.6404e-04 - val_loss: 6.7277e-04
# Epoch 34/60
# 352/352 [==============================] - 2s 4ms/step - loss: 2.7811e-05 - val_loss: 1.1952e-04
# Epoch 35/60
# 352/352 [==============================] - 2s 5ms/step - loss: 5.8159e-05 - val_loss: 2.6459e-04
# Epoch 36/60
# 352/352 [==============================] - 2s 4ms/step - loss: 4.0361e-05 - val_loss: 0.0019
# Epoch 37/60
# 352/352 [==============================] - 2s 5ms/step - loss: 1.0739e-04 - val_loss: 1.5562e-04
# Epoch 38/60
# 352/352 [==============================] - 2s 5ms/step - loss: 6.9609e-05 - val_loss: 4.5950e-04
# Epoch 39/60
# 352/352 [==============================] - 2s 5ms/step - loss: 9.5533e-05 - val_loss: 3.1737e-04
# Epoch 40/60
# 352/352 [==============================] - 2s 5ms/step - loss: 4.7279e-05 - val_loss: 7.1294e-04
# Epoch 41/60
# 352/352 [==============================] - 2s 5ms/step - loss: 7.1378e-05 - val_loss: 7.5538e-04
# Epoch 42/60
# 352/352 [==============================] - 2s 5ms/step - loss: 6.1949e-05 - val_loss: 7.6023e-04
# Epoch 43/60
# 352/352 [==============================] - 2s 5ms/step - loss: 3.5056e-05 - val_loss: 6.6386e-04
# Epoch 44/60
# 352/352 [==============================] - 2s 5ms/step - loss: 7.0686e-05 - val_loss: 1.1339e-04
# Epoch 45/60
# 352/352 [==============================] - 2s 5ms/step - loss: 3.5843e-05 - val_loss: 0.0012
# Epoch 46/60
# 352/352 [==============================] - 2s 4ms/step - loss: 2.8651e-04 - val_loss: 0.0097
# Epoch 47/60
# 352/352 [==============================] - 2s 4ms/step - loss: 2.5035e-04 - val_loss: 4.5709e-04
# Epoch 48/60
# 352/352 [==============================] - 2s 4ms/step - loss: 4.8439e-05 - val_loss: 7.2387e-04
# Epoch 49/60
# 352/352 [==============================] - 2s 4ms/step - loss: 2.3495e-05 - val_loss: 6.2129e-04
# Epoch 50/60
# 352/352 [==============================] - 2s 5ms/step - loss: 3.9668e-05 - val_loss: 1.1235e-04
# Epoch 51/60
# 352/352 [==============================] - 2s 5ms/step - loss: 8.6635e-05 - val_loss: 2.5586e-04
# Epoch 52/60
# 352/352 [==============================] - 2s 5ms/step - loss: 2.3746e-05 - val_loss: 5.9350e-04
# Epoch 53/60
# 352/352 [==============================] - 2s 5ms/step - loss: 2.1367e-05 - val_loss: 7.0149e-04
# Epoch 54/60
# 352/352 [==============================] - 2s 4ms/step - loss: 4.8797e-05 - val_loss: 3.5629e-04
# Epoch 55/60
# 352/352 [==============================] - 2s 5ms/step - loss: 4.4368e-05 - val_loss: 7.2091e-04
# Epoch 56/60
# 352/352 [==============================] - 2s 4ms/step - loss: 5.0448e-05 - val_loss: 6.4783e-05
# Epoch 57/60
# 352/352 [==============================] - 2s 4ms/step - loss: 2.7581e-05 - val_loss: 2.0501e-04
# Epoch 58/60
# 352/352 [==============================] - 2s 5ms/step - loss: 1.0690e-04 - val_loss: 6.2627e-05
# Epoch 59/60
# 352/352 [==============================] - 2s 5ms/step - loss: 4.3269e-05 - val_loss: 1.3092e-04
# Epoch 60/60
# 352/352 [==============================] - 2s 5ms/step - loss: 4.0031e-05 - val_loss: 1.8296e-04
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_8 (LSTM)               (None, 3, 22)             2112
#
#  lstm_9 (LSTM)               (None, 22)                3960
#
#  dense_4 (Dense)             (None, 1)                 23
#
# =================================================================
# Total params: 6,095
# Trainable params: 6,095
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 352/352 [==============================] - 4s 6ms/step - loss: 0.0388 - val_loss: 3.7686e-04
# Epoch 2/50
# 352/352 [==============================] - 1s 4ms/step - loss: 1.2867e-04 - val_loss: 8.2442e-04
# Epoch 3/50
# 352/352 [==============================] - 2s 4ms/step - loss: 7.1587e-05 - val_loss: 4.4109e-05
# Epoch 4/50
# 352/352 [==============================] - 2s 5ms/step - loss: 2.8904e-05 - val_loss: 2.2964e-04
# Epoch 5/50
# 352/352 [==============================] - 2s 5ms/step - loss: 2.0968e-05 - val_loss: 1.5833e-04
# Epoch 6/50
# 352/352 [==============================] - 2s 4ms/step - loss: 1.9559e-05 - val_loss: 1.0756e-04
# Epoch 7/50
# 352/352 [==============================] - 2s 5ms/step - loss: 3.4998e-05 - val_loss: 2.1991e-05
# Epoch 8/50
# 352/352 [==============================] - 2s 5ms/step - loss: 3.0509e-05 - val_loss: 4.4875e-05
# Epoch 9/50
# 352/352 [==============================] - 2s 5ms/step - loss: 8.2974e-05 - val_loss: 1.9290e-04
# Epoch 10/50
# 352/352 [==============================] - 2s 5ms/step - loss: 2.6475e-05 - val_loss: 5.7734e-05
# Epoch 11/50
# 352/352 [==============================] - 2s 5ms/step - loss: 5.0241e-04 - val_loss: 1.8826e-04
# Epoch 12/50
# 352/352 [==============================] - 2s 4ms/step - loss: 5.3158e-05 - val_loss: 4.4675e-04
# Epoch 13/50
# 352/352 [==============================] - 2s 4ms/step - loss: 3.1040e-05 - val_loss: 1.8360e-04
# Epoch 14/50
# 352/352 [==============================] - 2s 5ms/step - loss: 4.7038e-05 - val_loss: 5.5156e-04
# Epoch 15/50
# 352/352 [==============================] - 2s 5ms/step - loss: 2.8604e-05 - val_loss: 1.9900e-04
# Epoch 16/50
# 352/352 [==============================] - 2s 5ms/step - loss: 5.0069e-05 - val_loss: 1.8161e-05
# Epoch 17/50
# 148/352 [===========>..................] - ETA: 0s - loss: 2.7215e-05

# %%
metrics = pd.DataFrame({'MAE_4': MAE_4, 'MAPE_4 1 Day': MAPE_4_Next_day,
     'MAPE_4 3 Days': MAPE_4_3days,'MAPE_4 7 days': MAPE_4_7days, 'MAPE_4': MAPE_4, 'MSE_4': MSE_4, 'RMSE_4': RMSE_4, 'Nodes': node , 'Epochs' : Epochs})

# metrics =metrics.append( metrics.groupby(['Nodes'  , 'Epochs']).mean())
metrics = metrics.groupby(['Nodes' , 'Epochs']).mean()
metrics.to_csv("Results.csv", float_format="%.5f",index=True, header=True)
